# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np
import plotly.express as px
import hvplot.pandas

# %%
# Load the GDP data
gdp_df = pd.read_csv('..\Resources\gdp_pop_medals\gpd_medals_total.csv')
# drop unused columns
# gdp_df = gdp_df.drop(['Season','Country_Name','Gold','Silver','Bronze','Total_Medals'],1)
gdp_df = gdp_df.drop(['Season','Country_Name','Gold','Silver','Bronze'],1)
gdp_df.head()
# Out:
# C:\Users\Public\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:5: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   Country_Code  Year          GDP  Total_Medals
# 0          ARG  1960          NaN             2
# 1          AUS  1960  1810.510249            22
# 2          AUT  1960   935.460427             2
# 3          AUT  1960   935.460427             6
# 4          BEL  1960  1273.691659             4

# %%
Country_Codes = gdp_df.Country_Code.unique()
gdp_df['cumulative'] = 0

# %%
for code in Country_Codes:
    gdp_df.loc[gdp_df['Country_Code'] == code,['cumulative']] = gdp_df.loc[gdp_df['Country_Code'] == code]['Total_Medals'].cumsum()

# %%
gdp_df.loc[gdp_df['Country_Code'] == 'ARG']['Total_Medals'].cumsum().index.values
# Out:
# array([  0,  38,  76, 116, 280, 324, 398, 471, 544, 617, 699, 779, 862],
#       dtype=int64)

# %%
gdp_df
# Out:
#     Country_Code  Year           GDP  Total_Medals  cumulative
# 0            ARG  1960           NaN             2           2
# 1            AUS  1960   1810.510249            22          22
# 2            AUT  1960    935.460427             2           2
# 3            AUT  1960    935.460427             6           8
# 4            BEL  1960   1273.691659             4           4
# ..           ...   ...           ...           ...         ...
# 921          UGA  2020    846.767201             4          11
# 922          UKR  2020   3751.740723            19         147
# 923          USA  2020  63530.633480           113        1826
# 924          UZB  2020   1749.655815             5          37
# 925          VEN  2020           NaN             4          18
#
# [926 rows x 5 columns]

# %%
# Load the population data
population_df = pd.read_csv('..\Resources\gdp_pop_medals\pop_medals_total.csv')
# drop unused columns
population_df = population_df.drop(['Season','Country_Name','Gold','Silver','Bronze','Total_Medals'],1)
population_df.head()
# Out:
# C:\Users\Public\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:4: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   Country_Code  Year  Population
# 0          ARG  1960  20349744.0
# 1          AUS  1960  10276477.0
# 2          AUT  1960   7047539.0
# 3          AUT  1960   7047539.0
# 4          BEL  1960   9153489.0

# %%
# Merge the data into one dataframe
result = []
result = pd.merge(gdp_df, population_df, how='left', on=["Country_Code", "Year"])
result
# Out:
#      Country_Code  Year           GDP  Total_Medals  cumulative   Population
# 0             ARG  1960           NaN             2           2   20349744.0
# 1             AUS  1960   1810.510249            22          22   10276477.0
# 2             AUT  1960    935.460427             2           2    7047539.0
# 3             AUT  1960    935.460427             2           2    7047539.0
# 4             AUT  1960    935.460427             6           8    7047539.0
# ...           ...   ...           ...           ...         ...          ...
# 1091          UGA  2020    846.767201             4          11   44404611.0
# 1092          UKR  2020   3751.740723            19         147   44132049.0
# 1093          USA  2020  63530.633480           113        1826  331501080.0
# 1094          UZB  2020   1749.655815             5          37   34232050.0
# 1095          VEN  2020           NaN             4          18   28490453.0
#
# [1096 rows x 6 columns]

# %%
# find amount of NaN values
result.isna().sum()
# Out:
# Country_Code     0
# Year             0
# GDP             66
# Total_Medals     0
# cumulative       0
# Population       0
# dtype: int64

# %%
# drop NaN values in the following columns
result = result.dropna()
result
# Out:
#      Country_Code  Year           GDP  Total_Medals  cumulative   Population
# 1             AUS  1960   1810.510249            22          22   10276477.0
# 2             AUT  1960    935.460427             2           2    7047539.0
# 3             AUT  1960    935.460427             2           2    7047539.0
# 4             AUT  1960    935.460427             6           8    7047539.0
# 5             AUT  1960    935.460427             6           8    7047539.0
# ...           ...   ...           ...           ...         ...          ...
# 1090          TUR  2020   8561.070948            13          79   84135428.0
# 1091          UGA  2020    846.767201             4          11   44404611.0
# 1092          UKR  2020   3751.740723            19         147   44132049.0
# 1093          USA  2020  63530.633480           113        1826  331501080.0
# 1094          UZB  2020   1749.655815             5          37   34232050.0
#
# [1030 rows x 6 columns]

# %%
# find amount of NaN values remaining
result.isna().sum()
# Out:
# Country_Code    0
# Year            0
# GDP             0
# Total_Medals    0
# cumulative      0
# Population      0
# dtype: int64

# %%
result
# Out:
#      Country_Code  Year           GDP  Total_Medals  cumulative   Population
# 1             AUS  1960   1810.510249            22          22   10276477.0
# 2             AUT  1960    935.460427             2           2    7047539.0
# 3             AUT  1960    935.460427             2           2    7047539.0
# 4             AUT  1960    935.460427             6           8    7047539.0
# 5             AUT  1960    935.460427             6           8    7047539.0
# ...           ...   ...           ...           ...         ...          ...
# 1090          TUR  2020   8561.070948            13          79   84135428.0
# 1091          UGA  2020    846.767201             4          11   44404611.0
# 1092          UKR  2020   3751.740723            19         147   44132049.0
# 1093          USA  2020  63530.633480           113        1826  331501080.0
# 1094          UZB  2020   1749.655815             5          37   34232050.0
#
# [1030 rows x 6 columns]

# %%
result['GDP'] = result['GDP']*result['Population']
result
# Out:
# C:\Users\Public\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Country_Code  Year           GDP  Total_Medals  cumulative   Population
# 1             AUS  1960  1.860567e+10            22          22   10276477.0
# 2             AUT  1960  6.592694e+09             2           2    7047539.0
# 3             AUT  1960  6.592694e+09             2           2    7047539.0
# 4             AUT  1960  6.592694e+09             6           8    7047539.0
# 5             AUT  1960  6.592694e+09             6           8    7047539.0
# ...           ...   ...           ...           ...         ...          ...
# 1090          TUR  2020  7.202894e+11            13          79   84135428.0
# 1091          UGA  2020  3.760037e+10             4          11   44404611.0
# 1092          UKR  2020  1.655720e+11            19         147   44132049.0
# 1093          USA  2020  2.106047e+13           113        1826  331501080.0
# 1094          UZB  2020  5.989431e+10             5          37   34232050.0
#
# [1030 rows x 6 columns]

# %%
fig = px.scatter_3d(result, x="GDP", y="Population", z="cumulative", width=800)
fig.update_layout(legend=dict(x=0,y=1))
fig.show()
# Out:
# <div>                            <div id="3f6a7863-7c39-4ec5-9545-02e3e6ecba6a" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f6a7863-7c39-4ec5-9545-02e3e6ecba6a")) {                    Plotly.newPlot(                        "3f6a7863-7c39-4ec5-9545-02e3e6ecba6a",                        [{"hovertemplate":"GDP=%{x}<br>Population=%{y}<br>cumulative=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[18605666932.112774,6592693841.534399,6592693841.534399,6592693841.534399,6592693841.534399,11658722590.048252,17030465543.012688,40461721694.680916,40461721694.680916,40461721694.680916,40461721694.680916,12072126074.2515,5224102195.527974,5224102195.527974,5224102195.527974,5224102195.527974,62225478007.09517,62225478007.09517,62225478007.09517,62225478007.09517,73233967677.2,1217086834.8730838,37029883874.36023,1684121534.318556,40385288341.87301,40385288341.87301,40385288341.87301,40385288341.87301,44307342951.1296,2031451031.9556613,13040000000.177885,5163271598.06274,5163271598.06274,5163271598.06274,5163271598.06274,5485854791.0255995,3749265014.87429,704756304.672,15822585035.882288,15822585035.882288,15822585035.882288,15822585035.882288,13983572893.932936,543299999931.59503,543299999931.59503,543299999931.59503,543299999931.59503,7779090909.128915,25605249377.87973,23799977595.719,9169983886.487984,15960106684.957188,20963733692.055313,49377522896.450005,49377522896.450005,49377522896.450005,49377522896.450005,7766655084.662334,7766655084.662334,7766655084.662334,7766655084.662334,94007851070.0698,94007851070.0698,94007851070.0698,94007851070.0698,94407558372.0,94407558372.0,94407558372.0,94407558372.0,1731092436.965532,56480289962.166595,2766608945.9406853,63175416995.089005,63175416995.089005,63175416995.089005,63175416995.089005,81749006377.28549,998759333.8896496,3459032882.8693194,20079999999.0939,7159202707.000146,7274144351.750401,5204955899.409062,22532416746.549244,22532416746.549244,22532416746.549244,22532416746.549244,711893367.5891833,11177777778.857014,685800000048.465,685800000048.465,685800000048.465,685800000048.465,26436857251.861588,32712509803.356,12440625312.551785,12440625312.551785,12440625312.551785,12440625312.551785,21376353118.100315,33930457429.557503,71829810520.768,71829810520.768,71829810520.768,71829810520.768,1046191192.4069402,8823033879.512568,8823033879.512568,8823033879.512568,8823033879.512568,129785441493.24786,129785441493.24786,129785441493.24786,129785441493.24786,107759910074.7732,53085455869.13175,87942231689.12775,87942231689.12775,87942231689.12775,87942231689.12775,1083883355.283703,146601072717.733,1353295457.3562756,6119284293.975996,29359999997.824368,10159934138.57311,10159934138.57311,10159934138.57311,10159934138.57311,5180597621.3112,8041999161.0853,31066819925.56927,31066819925.56927,31066819925.56927,31066819925.56927,1214666666.6360219,17499999999.679672,1037815126.136117,942499999913.34,942499999913.34,942499999913.34,942499999913.34,10034444444.901415,34733000528.63922,52042056069.811005,22059612477.00068,22059612477.00068,22059612477.00068,22059612477.00068,37209418018.5685,58434858371.32246,113082820485.83463,113082820485.83463,113082820485.83463,113082820485.83463,8671358732.444626,8135150891.481436,59132415229.163,59132415229.163,59132415229.163,59132415229.163,14743186120.164557,14743186120.164557,14743186120.164557,14743186120.164557,203494148221.5552,203494148221.5552,203494148221.5552,203494148221.5552,169965034958.3174,2112292944.735725,71463193804.21297,145260039815.00732,145260039815.00732,145260039815.00732,145260039815.00732,1875048859.9339585,318031297467.248,318031297467.248,318031297467.248,318031297467.248,2107279 ...

# %%
result.hvplot.scatter(x="GDP", y="cumulative")
# Out:
# :Scatter   [GDP]   (cumulative)

# %%
print("Number of rows:", result.shape[0])
# Out:
# Number of rows: 1030

# %%
# dropping columns unimportant to machine learning.
result = result.drop(['Year','Country_Code', 'Total_Medals'],1)
# Out:
# C:\Users\Public\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
# Print the names of the new columns
print(result.columns)
# Out:
# Index(['GDP', 'cumulative', 'Population'], dtype='object')

# %%
# Split the data into features and target
X = result.drop('cumulative', axis=1).values.reshape(-1, 2)
y = result['cumulative']

# %%
X.shape
# Out:
# (1030, 2)

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (1030,)

# %%
# Evaluate the model
score = model.score(X, y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.7813479365373175

# %%
matrix = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(
   matrix, index=["Actual 0", "Actual 1"],
   columns=["Predicted 0", "Predicted 1"]
)
display(cm_df)
# Out:
#           Predicted 0  Predicted 1
# Actual 0        37869         1843
# Actual 1         1995         4659

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     39712
#            1       0.72      0.70      0.71      6654
#
#     accuracy                           0.92     46366
#    macro avg       0.83      0.83      0.83     46366
# weighted avg       0.92      0.92      0.92     46366
