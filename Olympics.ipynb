# %%
import pandas as pd


gdp_df = pd.read_csv("Resources/gdp_1960_2021.csv")
gdp_df.head()
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                  Afghanistan          AFG  GDP per capita (current US$)
# 3   Africa Western and Central          AFW  GDP per capita (current US$)
# 4                       Angola          AGO  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  162.907576  162.546236  171.996697  199.182564  179.381788
# 2  NY.GDP.PCAP.CD   62.369375   62.443703   60.950364   82.021738   85.511073
# 3  NY.GDP.PCAP.CD  106.976475  112.047561  117.730633  122.278715  130.599963
# 4  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
# medals_per_country_df = pd.read_csv("Resources/olympics_medals_country_wise.csv")
# medals_per_country_df['ioc_code '] = medals_per_country_df['ioc_code '].str.replace(r'\(|\)', '')
# medals_per_country_df = medals_per_country_df.rename(columns={"ioc_code ": "Country Code", "countries ": "Country Name"})
# medals_per_country_df.head()

# %%
pop_df = pd.read_csv("Resources/population_1960_2021.csv")
pop_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2012         2013         2014         2015  \
# ...

# %%
athletes_df = pd.read_csv("Resources/althete_events_1896_2016.csv")
athletes_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9756\3945101683.py in <module>
# ----> 1 athletes_df = pd.read_csv("Resources/althete_events_1896_2016.csv")
#       2 athletes_df.head()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
