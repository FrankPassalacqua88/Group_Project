# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
# Import data
df = pd.read_csv('../Resources/Cleaning2/merged_events_bio.csv')
df.head(10)
# Out:
#    Athlete_ID                 Name   Age Sex  Height(cm)  Weight(kg)  \
# 0       16809       Károly Teppert  21.0   M         NaN         NaN
# 1       16809       Károly Teppert  21.0   M         NaN         NaN
# 2       43737    Andrzej Socharski  29.0   M       173.0        72.0
# 3       50147  Nathalie Wunderlich  21.0   F       170.0        50.0
# 4       50147  Nathalie Wunderlich  21.0   F       170.0        50.0
# 5       50147  Nathalie Wunderlich  21.0   F       170.0        50.0
# 6        5085           Miha Lokar  25.0   M       182.0        76.0
# 7      136329          Austin Hack  24.0   M       203.0       100.0
# 8      136329          Austin Hack  28.0   M       203.0       100.0
# 9       38633     Tsuneo Ogasawara  22.0   M       181.0        80.0
#
#           Sport    Country_Name Country_Code  Year  Season  isTeamSport Medal  \
# 0  Cycling Road         Hungary          HUN  1912  Summer        False    na
# 1  Cycling Road         Hungary          HUN  1912  Summer         True    na
# 2      Shooting          Poland          POL  1976  Summer        False    na
# 3      Swimming     Switzerland          SUI  1992  Summer        False    na
# 4      Swimming     Switzerland          SUI  1992  Summer        False    na
# 5      Swimming     Switzerland          SUI  1992  Summer        False    na
# 6    Basketball      Yugoslavia          YUG  1960  Summer         True    na
# 7        Rowing   United States          USA  2016  Summer         True    na
# 8        Rowing   United States          USA  2020  Summer         True    na
# 9        Rowing           Japan          JPN  1964  Summer         True    na
#
#    Result_ID
# 0     153233
# 1     153234
# 2      51745
# 3       7860
# 4       7870
# 5       7919
# 6      32115
# 7     354004
# 8   19008478
# 9     158458

# %%
# Define the medal colors
colors = {'Gold': 'gold', 'Silver': 'silver', 'Bronze': 'brown'}

# %%
# Set a filter on the year
year = 2020

# %%
# Filter the data to exclude rows with no medal
df = df[(df['Medal'].isin(['Gold', 'Silver', 'Bronze'])) & (df['Year'] == year)]

# %%
# Create scatter plot
fig = go.Figure()

for medal in colors:
    fig.add_trace(go.Scatter(
        x=df[df['Medal'] == medal]['Weight(kg)'],
        y=df[df['Medal'] == medal]['Height(cm)'],
        mode='markers',
        marker=dict(
            size=10,
            color=df[df['Medal'] == medal]['Medal'].map(colors),
            symbol=df[df['Medal'] == medal]['Sex'].map({'M': 'square', 'F': 'circle'})
        ),
        name=medal,
        visible=False  # Hide traces by default
    ))

# %%
# Show the first trace by default
fig.data[0].visible = True

# %%
# Update the layout
fig.update_layout(
    title='Height vs. Weight by Medal',
    xaxis_title='Weight (kg)',
    yaxis_title='Height (cm)',
    updatemenus=[dict(
        type='buttons',
        direction='left',
        buttons=list([
            dict(
                label='All',
                method='update',
                args=[{'visible': [True, True, True]}]
            ),
            dict(
                label='M',
                method='update',
                args=[{'visible': [True, False, True]}]
            ),
            dict(
                label='F',
                method='update',
                args=[{'visible': [False, True, True]}]
            )
        ]),
        showactive=True,
        x=0.1,
        y=1.1
    )]
)
# Show the plot
fig.show()
